# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/data_row.csv', sep=';')

# %%
df.head()
# Out:
#    ID        Start time   Completion time      Email  Name  \
# 0   1  5.15.25 10:47:23  5.15.25 10:51:28  anonymous   NaN
# 1   2  5.15.25 11:45:30  5.15.25 11:50:26  anonymous   NaN
# 2   3  5.15.25 12:56:29  5.15.25 12:57:24  anonymous   NaN
# 3   4  5.15.25 16:01:37  5.15.25 16:03:54  anonymous   NaN
# 4   5   5.19.25 8:07:00   5.19.25 8:08:45  anonymous   NaN
#
#    Last modified time Was ist dein Geschlecht?  \
# 0                 NaN                 Männlich
# 1                 NaN                 Weiblich
# 2                 NaN                 Männlich
# 3                 NaN                 Weiblich
# 4                 NaN                 Weiblich
#
#    Wie viel schläfst im Durchschnitt? (Wochentag/Uni)  \
# 0                                                  8
# 1                                                  7
# 2                                                  5
# 3                                                  7
# 4                                                  7
#
#    Wie schätzt du deinen durchschnittliche Schlafqualität ein?  \
# 0                                                  3
# 1                                                  6
# 2                                                  5
# 3                                                  7
# 4                                                  6
#
#   Machst du Sport?  Wie viele Stunden pro Woche machst du Sport?  \
# 0              Ja                                            6.0
# 1              Ja                                           13.0
# 2              Ja                                            6.0
# 3              Ja                                            5.0
# 4              Ja                                            4.0
#
#    Wie viel Screentime hast du im Durchschnitt (pro Tag) ?
# 0                                                NaN
# 1                                                NaN
# 2                                               11.0
# 3                                                3.0
# 4                                                3.0

# %%
df.columns
# Out:
# Index(['ID', 'Start time', 'Completion time', 'Email', 'Name',
#        'Last modified time', 'Was ist dein Geschlecht?',
#        'Wie viel schläfst im Durchschnitt? (Wochentag/Uni)',
#        'Wie schätzt du deinen durchschnittliche Schlafqualität ein?',
#        'Machst du Sport?', 'Wie viele Stunden pro Woche machst du Sport?',
#        'Wie viel Screentime hast du im Durchschnitt (pro Tag) ?'],
#       dtype='object')

# %%
column_rename_map = {
    'ID': 'id',
    'Start time': 'start_time',
    'Completion time': 'completion_time',
    'Email': 'email',
    'Name': 'name',
    'Last modified time': 'last_modified_time',
    'Was ist dein Geschlecht?': 'gender',
    'Wie viel schläfst im Durchschnitt? (Wochentag/Uni)': 'sleep_hours_weekday',
    'Wie schätzt du deinen durchschnittliche Schlafqualität ein?': 'sleep_quality',
    'Machst du Sport?': 'does_sport',
    'Wie viele Stunden pro Woche machst du Sport?': 'sport_hours_per_week',
    'Wie viel Screentime hast du im Durchschnitt (pro Tag) ?': 'screentime_hours_per_day'
}
df = df.rename(columns=column_rename_map)
df.head()
# Out:
#    id        start_time   completion_time      email  name  \
# 0   1  5.15.25 10:47:23  5.15.25 10:51:28  anonymous   NaN
# 1   2  5.15.25 11:45:30  5.15.25 11:50:26  anonymous   NaN
# 2   3  5.15.25 12:56:29  5.15.25 12:57:24  anonymous   NaN
# 3   4  5.15.25 16:01:37  5.15.25 16:03:54  anonymous   NaN
# 4   5   5.19.25 8:07:00   5.19.25 8:08:45  anonymous   NaN
#
#    last_modified_time    gender  sleep_hours_weekday  sleep_quality  \
# 0                 NaN  Männlich                    8              3
# 1                 NaN  Weiblich                    7              6
# 2                 NaN  Männlich                    5              5
# 3                 NaN  Weiblich                    7              7
# 4                 NaN  Weiblich                    7              6
#
#   does_sport  sport_hours_per_week  screentime_hours_per_day
# 0        Ja                    6.0                       NaN
# 1        Ja                   13.0                       NaN
# 2        Ja                    6.0                      11.0
# 3        Ja                    5.0                       3.0
# 4        Ja                    4.0                       3.0

# %%
df = df[['id', 'gender', 'sleep_hours_weekday', 'sleep_quality', 'does_sport', 'sport_hours_per_week', 'screentime_hours_per_day']]
df.head()
# Out:
#    id    gender  sleep_hours_weekday  sleep_quality does_sport  \
# 0   1  Männlich                    8              3        Ja
# 1   2  Weiblich                    7              6        Ja
# 2   3  Männlich                    5              5        Ja
# 3   4  Weiblich                    7              7        Ja
# 4   5  Weiblich                    7              6        Ja
#
#    sport_hours_per_week  screentime_hours_per_day
# 0                   6.0                       NaN
# 1                  13.0                       NaN
# 2                   6.0                      11.0
# 3                   5.0                       3.0
# 4                   4.0                       3.0

# %%
# for some reason, the 'does_sport' column has leading/trailing spaces and inconsistent casing
df['does_sport'] = df['does_sport'].str.strip().str.lower()

# %%
df.loc[df.does_sport == 'nein']
# Out:
#     id    gender  sleep_hours_weekday  sleep_quality does_sport  \
# 7    8  Weiblich                    6              6       nein
# 9   10  Weiblich                    4              0       nein
# 16  17  Weiblich                    7              8       nein
# 20  21  Weiblich                    4              1       nein
# 25  26  Männlich                    5              6       nein
# 27  28  Männlich                    2              0       nein
# 28  29  Weiblich                    5              3       nein
# 29  30  Männlich                    4              4       nein
# 30  31  Weiblich                    7              4       nein
# 31  32  Weiblich                    3              6       nein
# 32  33  Weiblich                    5              4       nein
# 33  34  Weiblich                    7              5       nein
# 36  37  Männlich                    6              4       nein
# 37  38  Weiblich                    5              8       nein
# 38  39  Weiblich                   12             10       nein
# 41  42  Weiblich                    2              2       nein
# 43  44  Männlich                    9              9       nein
# 44  45  Männlich                    6              5       nein
# 45  46  Weiblich                    6              6       nein
# 47  48  Weiblich                    6              2       nein
# 48  49  Weiblich                    6              4       nein
# 50  51  Männlich                    6              3       nein
#
#     sport_hours_per_week  screentime_hours_per_day
# 7                    1.0                      10.0
# 9                    1.0                       4.0
# 16                   0.0                       7.0
# 20                   1.0                       4.0
# 25                   0.0                       7.0
# 27                   0.0                       6.0
# 28                   2.0                       3.0
# 29                   NaN                       2.0
# 30                   NaN                       8.0
# 31                   NaN                       4.0
# 32                   NaN                      12.0
# 33                   NaN                       7.0
# 36                   NaN                       8.0
# 37                   NaN                       3.0
# 38                   NaN                       2.0
# 41                   NaN                      12.0
# 43                   NaN                       8.0
# 44                   NaN                       3.0
# 45                   NaN                       7.0
# 47                   NaN                       6.0
# 48                   NaN                       6.0
# 50                   NaN                       7.0

# %%
# `does_sport` sagt nein, aber die Leute haben trotzdem Sportstunden angegeben obwohl die meisten 0 sind
# also diese Spalte brauchen wir nicht, weil wir haben dann sowieso NaN in der Spalte `sport_hours_per_week`

# %%
df['is_male'] = (df.gender == 'Männlich').astype(int)
df = df.drop(columns=['gender', 'does_sport'])
df.head()
# Out:
#    id  sleep_hours_weekday  sleep_quality  sport_hours_per_week  \
# 0   1                    8              3                   6.0
# 1   2                    7              6                  13.0
# 2   3                    5              5                   6.0
# 3   4                    7              7                   5.0
# 4   5                    7              6                   4.0
#
#    screentime_hours_per_day  is_male
# 0                       NaN        1
# 1                       NaN        0
# 2                      11.0        1
# 3                       3.0        0
# 4                       3.0        0

# %%
df.isna().sum()
# Out:
# id                           0
# sleep_hours_weekday          0
# sleep_quality                0
# sport_hours_per_week        15
# screentime_hours_per_day     2
# is_male                      0
# dtype: int64

# %%
df.loc[df['sport_hours_per_week'].notna()]
# Out:
#     id  sleep_hours_weekday  sleep_quality  sport_hours_per_week  \
# 0    1                    8              3                   6.0
# 1    2                    7              6                  13.0
# 2    3                    5              5                   6.0
# 3    4                    7              7                   5.0
# 4    5                    7              6                   4.0
# 5    6                    7              8                   7.0
# 6    7                    6              3                  12.0
# 7    8                    6              6                   1.0
# 8    9                    5              4                   5.0
# 9   10                    4              0                   1.0
# 10  11                    6              6                   6.0
# 11  12                    8              9                   8.0
# 12  13                    5              4                   5.0
# 13  14                    4              0                   2.0
# 14  15                    5              4                   4.0
# 15  16                    4              4                   2.0
# 16  17                    7              8                   0.0
# 17  18                    8              8                   8.0
# 18  19                    5              4                   3.0
# 19  20                    5              7                   3.0
# 20  21                    4              1                   1.0
# 21  22                    5              6                   5.0
# 22  23                    3              4                   2.0
# 23  24                    4              3                   3.0
# 24  25                    3              4                   2.0
# 25  26                    5              6                   0.0
# 26  27                   10             10                   6.0
# 27  28                    2              0                   0.0
# 28  29                    5              3                   2.0
# 34  35                    5              5                   5.0
# 35  36                    8             10                   8.0
# 39  40                    6              3                   6.0
# 40  41                    6              6                   5.0
# 42  43                    9             10                  17.0
# 46  47                    6              6                   6.0
# 49  50                    6              6                   5.0
# 51  52                    8              8                  30.0
#
#     screentime_hours_per_day  is_male
# 0                        NaN        1
# 1                        NaN        0
# 2                       11.0        1
# 3                        3.0        0
# 4                        3.0        0
# 5                        4.0        1
# 6                        8.0        1
# 7                       10.0        0
# 8                        5.0        0
# 9                        4.0        0
# 10                       5.0        1
# 11                       2.0        0
# 12                       3.0        1
# 13                      12.0        0
# 14                       2.0        1
# 15                       1.0        0
# 16                       7.0        0
# 17                       8.0        1
# 18                       7.0        1
# 19                       7.0        1
# 20                       4.0        0
# 21                       8.0        0
# 22                       7.0        0
# 23                       5.0        1
# 24                       5.0        0
# 25                       7.0        1
# 26                       3.0        0
# 27                       6.0        1
# 28                       3.0        0
# 34                       5.0        1
# 35                       8.0        1
# 39                       5.0        0
# 40                       3.0        0
# 42                       8.0        1
# 46                       7.0        1
# 49                       7.0        1
# 51                       5.0        0

# %%
df.sport_hours_per_week = df.sport_hours_per_week.fillna(0)
df.screentime_hours_per_day = df.screentime_hours_per_day.fillna(0)

# %%
df.isna().sum()
# Out:
# id                          0
# sleep_hours_weekday         0
# sleep_quality               0
# sport_hours_per_week        0
# screentime_hours_per_day    0
# is_male                     0
# dtype: int64

# %%
df.shape
# Out:
# (52, 6)

# %%
df[['sport_hours_per_week', 'screentime_hours_per_day']] = df[['sport_hours_per_week', 'screentime_hours_per_day']].astype(int)
df.dtypes
# Out:
# id                          int64
# sleep_hours_weekday         int64
# sleep_quality               int64
# sport_hours_per_week        int64
# screentime_hours_per_day    int64
# is_male                     int64
# dtype: object

# %%
df
# Out:
#     id  sleep_hours_weekday  sleep_quality  sport_hours_per_week  \
# 0    1                    8              3                     6
# 1    2                    7              6                    13
# 2    3                    5              5                     6
# 3    4                    7              7                     5
# 4    5                    7              6                     4
# 5    6                    7              8                     7
# 6    7                    6              3                    12
# 7    8                    6              6                     1
# 8    9                    5              4                     5
# 9   10                    4              0                     1
# 10  11                    6              6                     6
# 11  12                    8              9                     8
# 12  13                    5              4                     5
# 13  14                    4              0                     2
# 14  15                    5              4                     4
# 15  16                    4              4                     2
# 16  17                    7              8                     0
# 17  18                    8              8                     8
# 18  19                    5              4                     3
# 19  20                    5              7                     3
# 20  21                    4              1                     1
# 21  22                    5              6                     5
# 22  23                    3              4                     2
# 23  24                    4              3                     3
# 24  25                    3              4                     2
# 25  26                    5              6                     0
# 26  27                   10             10                     6
# 27  28                    2              0                     0
# 28  29                    5              3                     2
# 29  30                    4              4                     0
# 30  31                    7              4                     0
# 31  32                    3              6                     0
# 32  33                    5              4                     0
# 33  34                    7              5                     0
# 34  35                    5              5                     5
# 35  36                    8             10                     8
# 36  37                    6              4                     0
# 37  38                    5              8                     0
# 38  39                   12             10                     0
# 39  40                    6              3                     6
# 40  41                    6              6                     5
# 41  42                    2              2                     0
# 42  43                    9             10                    17
# 43  44                    9              9                     0
# 44  45                    6              5                     0
# 45  46                    6              6                     0
# 46  47                    6              6                     6
# 47  48                    6              2                     0
# 48  49                    6              4                     0
# 49  50                    6              6                     5
# 50  51                    6              3                     0
# 51  52                    8              8                    30
#
#     screentime_hours_per_day  is_male
# 0                          0        1
# 1                          0        0
# 2                         11        1
# 3                          3        0
# 4                          3        0
# 5                          4        1
# 6                          8        1
# 7                         10        0
# 8                          5        0
# 9                          4        0
# 10                         5        1
# 11                         2        0
# 12                         3        1
# 13                        12        0
# 14                         2        1
# 15                         1        0
# 16                         7        0
# 17                         8        1
# 18                         7        1
# 19                         7        1
# 20                         4        0
# 21                         8        0
# 22                         7        0
# 23                         5        1
# 24                         5        0
# 25                         7        1
# 26                         3        0
# 27                         6        1
# 28                         3        0
# 29                         2        1
# 30                         8        0
# 31                         4        0
# 32                        12        0
# 33                         7        0
# 34                         5        1
# 35                         8        1
# 36                         8        1
# 37                         3        0
# 38                         2        0
# 39                         5        0
# 40                         3        0
# 41                        12        0
# 42                         8        1
# 43                         8        1
# 44                         3        1
# 45                         7        0
# 46                         7        1
# 47                         6        0
# 48                         6        0
# 49                         7        1
# 50                         7        1
# 51                         5        0

# %%
df.to_csv('../data/data_cleaned.csv', index=False)
